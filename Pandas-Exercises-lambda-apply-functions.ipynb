# %% [markdown]
# # Student Alcohol Consumption

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the datasets *student-mat* and *student-por* and merge them.

# %%
d1 = pd.read_csv("C:/Users/Yash/Desktop/STATS/CASE STUDY FOR PANDAS/2. Pandas Basic Exercises/Exercise Data Files/Pandas Exercise Lambda Functions Files/student-mat.csv")
d2 = pd.read_csv("C:/Users/Yash/Desktop/STATS/CASE STUDY FOR PANDAS/2. Pandas Basic Exercises/Exercise Data Files/Pandas Exercise Lambda Functions Files/student-mat.csv")

# %%
df = pd.merge(left = d1,right = d2,left_on = 'school',right_on = 'school',how = 'inner',indicator = True)

df.head()
# Out:
#   school sex_x  age_x address_x famsize_x Pstatus_x  Medu_x  Fedu_x   Mjob_x  \
# 0     GP     F     18         U       GT3         A       4       4  at_home
# 1     GP     F     18         U       GT3         A       4       4  at_home
# 2     GP     F     18         U       GT3         A       4       4  at_home
# 3     GP     F     18         U       GT3         A       4       4  at_home
# 4     GP     F     18         U       GT3         A       4       4  at_home
#
#     Fjob_x  ... freetime_y goout_y  Dalc_y  Walc_y  health_y absences_y G1_y  \
# 0  teacher  ...          3       4       1       1         3          6    5
# 1  teacher  ...          3       3       1       1         3          4    5
# 2  teacher  ...          3       2       2       3         3         10    7
# 3  teacher  ...          2       2       1       1         5          2   15
# 4  teacher  ...          3       2       1       2         5          4    6
#
#   G2_y G3_y _merge
# 0    6    6   both
# 1    5    6   both
# 2    8   10   both
# 3   14   15   both
# 4   10   10   both
#
# [5 rows x 66 columns]

# %% [markdown]
# ### Step 3. Assign it to a variable called df.

# %%
df
# Out:
#        school sex_x  age_x address_x famsize_x Pstatus_x  Medu_x  Fedu_x  \
# 0          GP     F     18         U       GT3         A       4       4
# 1          GP     F     18         U       GT3         A       4       4
# 2          GP     F     18         U       GT3         A       4       4
# 3          GP     F     18         U       GT3         A       4       4
# 4          GP     F     18         U       GT3         A       4       4
# ...       ...   ...    ...       ...       ...       ...     ...     ...
# 123912     MS     M     19         U       LE3         T       1       1
# 123913     MS     M     19         U       LE3         T       1       1
# 123914     MS     M     19         U       LE3         T       1       1
# 123915     MS     M     19         U       LE3         T       1       1
# 123916     MS     M     19         U       LE3         T       1       1
#
#          Mjob_x   Fjob_x  ... freetime_y goout_y  Dalc_y  Walc_y  health_y  \
# 0       at_home  teacher  ...          3       4       1       1         3
# 1       at_home  teacher  ...          3       3       1       1         3
# 2       at_home  teacher  ...          3       2       2       3         3
# 3       at_home  teacher  ...          2       2       1       1         5
# 4       at_home  teacher  ...          3       2       1       2         5
# ...         ...      ...  ...        ...     ...     ...     ...       ...
# 123912    other  at_home  ...          5       4       4       5         4
# 123913    other  at_home  ...          4       5       3       4         2
# 123914    other  at_home  ...          5       3       3       3         3
# 123915    other  at_home  ...          4       1       3       4         5
# 123916    other  at_home  ...          2       3       3       3         5
#
#        absences_y G1_y G2_y G3_y _merge
# 0               6    5    6    6   both
# 1               4    5    5    6   both
# 2              10    7    8   10   both
# 3               2   15   14   15   both
# 4               4    6   10   10   both
# ...           ...  ...  ...  ...    ...
# 123912         11    9    9    9   both
# 123913          3   14   16   16   both
# 123914          3   10    8    7   both
# 123915          0   11   12   10   both
# 123916          5    8    9    9   both
#
# [123917 rows x 66 columns]

# %% [markdown]
# ### Step 4. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
d1 = df.loc[: ,"school":"guardian_x"]
d1.head()
# Out:
#   school sex_x  age_x address_x famsize_x Pstatus_x  Medu_x  Fedu_x   Mjob_x  \
# 0     GP     F     18         U       GT3         A       4       4  at_home
# 1     GP     F     18         U       GT3         A       4       4  at_home
# 2     GP     F     18         U       GT3         A       4       4  at_home
# 3     GP     F     18         U       GT3         A       4       4  at_home
# 4     GP     F     18         U       GT3         A       4       4  at_home
#
#     Fjob_x reason_x guardian_x
# 0  teacher   course     mother
# 1  teacher   course     mother
# 2  teacher   course     mother
# 3  teacher   course     mother
# 4  teacher   course     mother

# %% [markdown]
# ### Step 5. Create a lambda function that captalize strings.

# %%
cap = lambda x: x.capitalize()

# %% [markdown]
# ### Step 6. Capitalize both Mjob and Fjob

# %%
d1['Mjob_x'].apply(cap)
d1['Fjob_x'].apply(cap)
# Out:
# 0         Teacher
# 1         Teacher
# 2         Teacher
# 3         Teacher
# 4         Teacher
#            ...
# 123912    At_home
# 123913    At_home
# 123914    At_home
# 123915    At_home
# 123916    At_home
# Name: Fjob_x, Length: 123917, dtype: object

# %% [markdown]
# ### Step 7. Print the last elements of the data set.

# %%
d1.tail()
# Out:
#        school sex_x  age_x address_x famsize_x Pstatus_x  Medu_x  Fedu_x  \
# 123912     MS     M     19         U       LE3         T       1       1
# 123913     MS     M     19         U       LE3         T       1       1
# 123914     MS     M     19         U       LE3         T       1       1
# 123915     MS     M     19         U       LE3         T       1       1
# 123916     MS     M     19         U       LE3         T       1       1
#
#        Mjob_x   Fjob_x reason_x guardian_x
# 123912  other  at_home   course     father
# 123913  other  at_home   course     father
# 123914  other  at_home   course     father
# 123915  other  at_home   course     father
# 123916  other  at_home   course     father

# %% [markdown]
# ### Step 8. Did you notice the original dataframe is still lowercase? Why is that? Fix it and captalize Mjob and Fjob.

# %%
d1['Mjob_x'] = d1['Mjob_x'].apply(cap)
d1['Fjob_x'] = d1['Fjob_x'].apply(cap)
d1.tail()
# Out:
#        school sex_x  age_x address_x famsize_x Pstatus_x  Medu_x  Fedu_x  \
# 123912     MS     M     19         U       LE3         T       1       1
# 123913     MS     M     19         U       LE3         T       1       1
# 123914     MS     M     19         U       LE3         T       1       1
# 123915     MS     M     19         U       LE3         T       1       1
# 123916     MS     M     19         U       LE3         T       1       1
#
#        Mjob_x   Fjob_x reason_x guardian_x
# 123912  Other  At_home   course     father
# 123913  Other  At_home   course     father
# 123914  Other  At_home   course     father
# 123915  Other  At_home   course     father
# 123916  Other  At_home   course     father

# %% [markdown]
# ### Step 9. Create a function called majority that return a boolean value to a new column called legal_drinker

# %%
def majority(x):
    if x > 17:
        return True
    else:
        return False

# %%
d1['legal_drinker_x'] = d1['age_x'].apply(majority)
d1.head()
# Out:
#   school sex_x  age_x address_x famsize_x Pstatus_x  Medu_x  Fedu_x   Mjob_x  \
# 0     GP     F     18         U       GT3         A       4       4  At_home
# 1     GP     F     18         U       GT3         A       4       4  At_home
# 2     GP     F     18         U       GT3         A       4       4  At_home
# 3     GP     F     18         U       GT3         A       4       4  At_home
# 4     GP     F     18         U       GT3         A       4       4  At_home
#
#     Fjob_x reason_x guardian_x  legal_drinker_x
# 0  Teacher   course     mother             True
# 1  Teacher   course     mother             True
# 2  Teacher   course     mother             True
# 3  Teacher   course     mother             True
# 4  Teacher   course     mother             True

# %% [markdown]
# ### Step 10. Multiply every number of the dataset by 10.

# %%
def Multiply(x):
    if type(x) is int:
        return 10 * x
    return x

# %%
d1.applymap(Multiply).head()
# Out:
#   school sex_x  age_x address_x famsize_x Pstatus_x  Medu_x  Fedu_x   Mjob_x  \
# 0     GP     F    180         U       GT3         A      40      40  At_home
# 1     GP     F    180         U       GT3         A      40      40  At_home
# 2     GP     F    180         U       GT3         A      40      40  At_home
# 3     GP     F    180         U       GT3         A      40      40  At_home
# 4     GP     F    180         U       GT3         A      40      40  At_home
#
#     Fjob_x reason_x guardian_x  legal_drinker_x
# 0  Teacher   course     mother             True
# 1  Teacher   course     mother             True
# 2  Teacher   course     mother             True
# 3  Teacher   course     mother             True
# 4  Teacher   course     mother             True
